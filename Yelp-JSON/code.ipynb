# %%
# %pip install pymongo neo4j
# Out:
# Collecting pymongo
#   Downloading pymongo-4.16.0-cp313-cp313-manylinux2014_x86_64.manylinux_2_17_x86_64.manylinux_2_28_x86_64.whl.metadata (10.0 kB)
# Requirement already satisfied: neo4j in /home/pranavanand/miniconda3/lib/python3.13/site-packages (6.1.0)
# Collecting dnspython<3.0.0,>=2.6.1 (from pymongo)
#   Downloading dnspython-2.8.0-py3-none-any.whl.metadata (5.7 kB)
# Requirement already satisfied: pytz in /home/pranavanand/.local/lib/python3.13/site-packages (from neo4j) (2025.2)
# Downloading pymongo-4.16.0-cp313-cp313-manylinux2014_x86_64.manylinux_2_17_x86_64.manylinux_2_28_x86_64.whl (2.0 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.0/2.0 MB 15.3 MB/s  0:00:00
# Downloading dnspython-2.8.0-py3-none-any.whl (331 kB)
# Installing collected packages: dnspython, pymongo
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2/2 [pymongo]m1/2 [pymongo]
# Successfully installed dnspython-2.8.0 pymongo-4.16.0
# Note: you may need to restart the kernel to use updated packages.

# %%
import json
from pymongo import MongoClient, InsertOne
from datetime import datetime

client = MongoClient("mongodb://localhost:27017/")
db = client["yelp_db"]

# ── CONFIG ──────────────────────────────────────────────────────────────────
DATA_DIR = r"/home/pranavanand/Projects/DSM/Yelp-Dataset-Assignment/Yelp-JSON"
REVIEW_LIMIT  = 200_000   # adjust if memory is tight
USER_LIMIT    = 100_000
CHECKIN_LIMIT = 50_000
TIP_LIMIT     = 50_000
BATCH         = 5_000
# ────────────────────────────────────────────────────────────────────────────

def load_jsonl(filepath, limit=None, transform=None):
    records = []
    with open(filepath, "r", encoding="utf-8") as f:
        for i, line in enumerate(f):
            if limit and i >= limit:
                break
            obj = json.loads(line)
            if transform:
                obj = transform(obj)
            records.append(obj)
    return records

def bulk_insert(collection, records, batch_size=BATCH):
    for i in range(0, len(records), batch_size):
        batch = records[i:i+batch_size]
        ops = [InsertOne(r) for r in batch]
        collection.bulk_write(ops, ordered=False)
    print(f"  Inserted {len(records)} docs into '{collection.name}'")

# ── BUSINESSES ───────────────────────────────────────────────────────────────
print("Loading businesses...")
def transform_business(b):
    b["_id"] = b.pop("business_id")
    if isinstance(b.get("categories"), str):
        b["categories"] = [c.strip() for c in b["categories"].split(",")]
    return b

businesses = load_jsonl(f"{DATA_DIR}/yelp_academic_dataset_business.json",
                        transform=transform_business)
db.businesses.drop()
bulk_insert(db.businesses, businesses)

# ── USERS ────────────────────────────────────────────────────────────────────
print("Loading users (subset)...")
def transform_user(u):
    u["_id"] = u.pop("user_id")
    if isinstance(u.get("friends"), str) and u["friends"]:
        u["friends"] = [x.strip() for x in u["friends"].split(",")]
    else:
        u["friends"] = []
    if isinstance(u.get("elite"), str) and u["elite"]:
        u["elite"] = [int(x.strip()) for x in u["elite"].split(",") if x.strip().isdigit()]
    return u

users = load_jsonl(f"{DATA_DIR}/yelp_academic_dataset_user.json",
                   limit=USER_LIMIT, transform=transform_user)
db.users.drop()
bulk_insert(db.users, users)

# ── REVIEWS ──────────────────────────────────────────────────────────────────
print("Loading reviews (subset)...")
def transform_review(r):
    r["_id"] = r.pop("review_id")
    r["date"] = datetime.strptime(r["date"], "%Y-%m-%d %H:%M:%S")
    return r

reviews = load_jsonl(f"{DATA_DIR}/yelp_academic_dataset_review.json",
                     limit=REVIEW_LIMIT, transform=transform_review)
db.reviews.drop()
bulk_insert(db.reviews, reviews)

# ── CHECKINS ─────────────────────────────────────────────────────────────────
print("Loading checkins (subset)...")
checkins = load_jsonl(f"{DATA_DIR}/yelp_academic_dataset_checkin.json",
                      limit=CHECKIN_LIMIT)
db.checkins.drop()
bulk_insert(db.checkins, checkins)

# ── TIPS ─────────────────────────────────────────────────────────────────────
print("Loading tips (subset)...")
tips = load_jsonl(f"{DATA_DIR}/yelp_academic_dataset_tip.json",
                  limit=TIP_LIMIT)
db.tips.drop()
bulk_insert(db.tips, tips)

# ── INDEXES ──────────────────────────────────────────────────────────────────
print("Creating indexes...")
db.reviews.create_index("business_id")
db.reviews.create_index("user_id")
db.reviews.create_index("date")
db.reviews.create_index([("business_id", 1), ("date", 1)])
db.businesses.create_index("city")
db.businesses.create_index("categories")
db.businesses.create_index([("city", 1), ("categories", 1)])
db.checkins.create_index("business_id")

print("Done.")
# Out:
# Loading businesses...
#   Inserted 150346 docs into 'businesses'
# Loading users (subset)...

# %%
# queries_mongo.py
from pymongo import MongoClient
import json
from datetime import datetime

client = MongoClient("mongodb://localhost:27017/")
db = client["yelp_db"]

def pprint(label, result):
    print(f"\n{'='*60}")
    print(f"  {label}")
    print('='*60)
    if isinstance(result, list):
        for r in result[:20]:   # cap output at 20 rows
            print(json.dumps(r, default=str, indent=2))
    else:
        print(json.dumps(result, default=str, indent=2))

# ── Q1: Safest / least-safe cities and categories by avg stars ───────────────
print("\n--- Q1 ---")

q1_city = list(db.reviews.aggregate([
    {"$group": {
        "_id": "$business_id",
        "avg_stars": {"$avg": "$stars"},
        "review_count": {"$sum": 1}
    }},
    {"$match": {"review_count": {"$gte": 10}}},
    {"$lookup": {
        "from": "businesses",
        "localField": "_id",
        "foreignField": "_id",
        "as": "biz"
    }},
    {"$unwind": "$biz"},
    {"$group": {
        "_id": "$biz.city",
        "avg_stars": {"$avg": "$avg_stars"},
        "total_reviews": {"$sum": "$review_count"},
        "business_count": {"$sum": 1}
    }},
    {"$match": {"business_count": {"$gte": 5}}},
    {"$sort": {"avg_stars": -1}},
]))
pprint("Q1 - Top 5 safest cities", q1_city[:5])
pprint("Q1 - Top 5 least-safe cities", q1_city[-5:])

q1_cat = list(db.reviews.aggregate([
    {"$group": {
        "_id": "$business_id",
        "avg_stars": {"$avg": "$stars"},
        "review_count": {"$sum": 1}
    }},
    {"$match": {"review_count": {"$gte": 10}}},
    {"$lookup": {
        "from": "businesses",
        "localField": "_id",
        "foreignField": "_id",
        "as": "biz"
    }},
    {"$unwind": "$biz"},
    {"$unwind": "$biz.categories"},
    {"$group": {
        "_id": "$biz.categories",
        "avg_stars": {"$avg": "$avg_stars"},
        "total_reviews": {"$sum": "$review_count"},
        "business_count": {"$sum": 1}
    }},
    {"$match": {"business_count": {"$gte": 10}}},
    {"$sort": {"avg_stars": -1}},
]))
pprint("Q1 - Top 5 categories by avg stars", q1_cat[:5])
pprint("Q1 - Bottom 5 categories by avg stars", q1_cat[-5:])

# ── Q2: Strongest upward/downward trends by city and category ────────────────
print("\n--- Q2 ---")

q2_city = list(db.reviews.aggregate([
    {"$group": {
        "_id": {
            "business_id": "$business_id",
            "year": {"$year": "$date"}
        },
        "avg_stars": {"$avg": "$stars"}
    }},
    {"$lookup": {
        "from": "businesses",
        "localField": "_id.business_id",
        "foreignField": "_id",
        "as": "biz"
    }},
    {"$unwind": "$biz"},
    {"$group": {
        "_id": {"city": "$biz.city", "year": "$_id.year"},
        "avg_stars": {"$avg": "$avg_stars"}
    }},
    {"$sort": {"_id.city": 1, "_id.year": 1}},
]))
# Compute slope per city in Python
from collections import defaultdict
import statistics

city_years = defaultdict(list)
for r in q2_city:
    city_years[r["_id"]["city"]].append((r["_id"]["year"], r["avg_stars"]))

def slope(points):
    if len(points) < 2:
        return 0
    xs = [p[0] for p in points]
    ys = [p[1] for p in points]
    n = len(xs)
    mx, my = sum(xs)/n, sum(ys)/n
    num = sum((x - mx)*(y - my) for x, y in zip(xs, ys))
    den = sum((x - mx)**2 for x in xs)
    return num / den if den else 0

city_slopes = [(c, slope(pts)) for c, pts in city_years.items() if len(pts) >= 3]
city_slopes.sort(key=lambda x: x[1], reverse=True)
pprint("Q2 - Cities with strongest upward trend (slope)", city_slopes[:5])
pprint("Q2 - Cities with strongest downward trend (slope)", city_slopes[-5:])

# ── Q3: Correlation between review volume and avg star rating ────────────────
print("\n--- Q3 ---")

q3 = list(db.reviews.aggregate([
    {"$group": {
        "_id": "$business_id",
        "avg_stars": {"$avg": "$stars"},
        "review_count": {"$sum": 1}
    }},
    {"$bucket": {
        "groupBy": "$review_count",
        "boundaries": [1, 10, 50, 100, 500, 1000, 10000],
        "default": "10000+",
        "output": {
            "avg_stars": {"$avg": "$avg_stars"},
            "business_count": {"$sum": 1}
        }
    }}
]))
pprint("Q3 - Avg stars by review count bucket", q3)

# ── Q4: Review behaviour by category ────────────────────────────────────────
print("\n--- Q4 ---")

q4 = list(db.reviews.aggregate([
    {"$lookup": {
        "from": "businesses",
        "localField": "business_id",
        "foreignField": "_id",
        "as": "biz"
    }},
    {"$unwind": "$biz"},
    {"$unwind": "$biz.categories"},
    {"$group": {
        "_id": "$biz.categories",
        "avg_stars": {"$avg": "$stars"},
        "avg_text_length": {"$avg": {"$strLenCP": "$text"}},
        "useful_per_review": {"$avg": "$useful"},
        "review_count": {"$sum": 1},
        "star_dist_1": {"$sum": {"$cond": [{"$eq": ["$stars", 1]}, 1, 0]}},
        "star_dist_2": {"$sum": {"$cond": [{"$eq": ["$stars", 2]}, 1, 0]}},
        "star_dist_3": {"$sum": {"$cond": [{"$eq": ["$stars", 3]}, 1, 0]}},
        "star_dist_4": {"$sum": {"$cond": [{"$eq": ["$stars", 4]}, 1, 0]}},
        "star_dist_5": {"$sum": {"$cond": [{"$eq": ["$stars", 5]}, 1, 0]}},
    }},
    {"$match": {"review_count": {"$gte": 200}}},
    {"$sort": {"review_count": -1}},
    {"$limit": 15}
]))
pprint("Q4 - Review behaviour by top categories", q4)

# ── Q5: Impact of user tenure on reviewing behaviour ─────────────────────────
print("\n--- Q5 ---")

q5 = list(db.reviews.aggregate([
    {"$lookup": {
        "from": "users",
        "localField": "user_id",
        "foreignField": "_id",
        "as": "user"
    }},
    {"$unwind": "$user"},
    {"$addFields": {
        "tenure_years": {
            "$divide": [
                {"$subtract": ["$date", {"$dateFromString": {"dateString": "$user.yelping_since"}}]},
                31536000000  # ms per year
            ]
        }
    }},
    {"$bucket": {
        "groupBy": "$tenure_years",
        "boundaries": [0, 1, 2, 3, 5, 8, 12, 20],
        "default": "20+",
        "output": {
            "avg_stars": {"$avg": "$stars"},
            "avg_useful": {"$avg": "$useful"},
            "review_count": {"$sum": 1}
        }
    }}
]))
pprint("Q5 - Reviewing behaviour by tenure", q5)

# ── Q6: Elite vs non-elite users ─────────────────────────────────────────────
print("\n--- Q6 ---")

q6 = list(db.reviews.aggregate([
    {"$lookup": {
        "from": "users",
        "localField": "user_id",
        "foreignField": "_id",
        "as": "user"
    }},
    {"$unwind": "$user"},
    {"$addFields": {
        "is_elite": {"$gt": [{"$size": {"$cond": [
          { "$isArray": "$user.elite" },
          "$user.elite",
          []
        ]}}, 0]}
    }},
    {"$group": {
        "_id": "$is_elite",
        "mean_stars": {"$avg": "$stars"},
        "mean_text_length": {"$avg": {"$strLenCP": "$text"}},
        "mean_useful": {"$avg": "$useful"},
        "review_count": {"$sum": 1}
    }}
]))
pprint("Q6 - Elite vs non-elite metrics", q6)

# ── Q7: Check-in activity vs star ratings ────────────────────────────────────
print("\n--- Q7 ---")

q7 = list(db.checkins.aggregate([
    {"$addFields": {
        "checkin_count": {
            "$size": {"$split": ["$date", ","]}
        }
    }},
    {"$lookup": {
        "from": "reviews",
        "localField": "business_id",
        "foreignField": "business_id",
        "as": "revs"
    }},
    {"$addFields": {
        "avg_stars": {"$avg": "$revs.stars"},
        "review_count": {"$size": "$revs"}
    }},
    {"$match": {"review_count": {"$gte": 5}}},
    {"$lookup": {
        "from": "businesses",
        "localField": "business_id",
        "foreignField": "_id",
        "as": "biz"
    }},
    {"$unwind": "$biz"},
    {"$unwind": "$biz.categories"},
    {"$group": {
        "_id": "$biz.categories",
        "avg_checkins": {"$avg": "$checkin_count"},
        "avg_stars": {"$avg": "$avg_stars"},
        "business_count": {"$sum": 1}
    }},
    {"$match": {"business_count": {"$gte": 10}}},
    {"$sort": {"avg_checkins": -1}},
    {"$limit": 20}
]))
pprint("Q7 - Checkin activity vs stars by category", q7)

print("\nAll queries done.")
# Out:
# --- Q1 ---
#
# ============================================================
#   Q1 - Top 5 safest cities
# ============================================================
# {
#   "_id": "Valrico",
#   "avg_stars": 4.4844841269841265,
#   "total_reviews": 154,
#   "business_count": 5
# }
# {
#   "_id": "Seminole",
#   "avg_stars": 4.170450382950383,
#   "total_reviews": 172,
#   "business_count": 7
# }
# {
#   "_id": "Trenton",
#   "avg_stars": 4.154141806128224,
#   "total_reviews": 113,
#   "business_count": 5
# }
# {
#   "_id": "Newtown",
#   "avg_stars": 4.148366831217077,
#   "total_reviews": 345,
#   "business_count": 7
# }
# {
#   "_id": "Lutz",
#   "avg_stars": 4.119673377697921,
#   "total_reviews": 382,
#   "business_count": 11
# }
#
# ============================================================
#   Q1 - Top 5 least-safe cities
# ============================================================
# {
#   "_id": "Plymouth Meeting",
#   "avg_stars": 3.0009986138172176,
#   "total_reviews": 305,
#   "business_count": 8
# }
# {
#   "_id": "Harvey",
#   "avg_stars": 2.958210878946173,
#   "total_reviews": 161,
#   "business_count": 5
# }
# {
#   "_id": "North Wales",
#   "avg_stars": 2.8694023291584267,
#   "total_reviews": 153,
#   "business_count": 5
# }
# {
#   "_id": "Downingtown",
#   "avg_stars": 2.8684199134199133,
#   "total_reviews": 146,
#   "business_count": 5
# }
# {
#   "_id": "Saint Charles",
#   "avg_stars": 2.3636363636363638,
#   "total_reviews": 61,
#   "business_count": 5
# }
#
# ============================================================
#   Q1 - Top 5 categories by avg stars
# ============================================================
# {
#   "_id": "Tattoo",
#   "avg_stars": 4.620743963358906,
#   "total_reviews": 231,
#   "business_count": 12
# }
# {
#   "_id": "Sewing & Alterations",
#   "avg_stars": 4.545826802507837,
#   "total_reviews": 202,
#   "business_count": 11
# }
# {
#   "_id": "Jewelry",
#   "avg_stars": 4.500965933602406,
#   "total_reviews": 329,
#   "business_count": 17
# }
# {
#   "_id": "Historical Tours",
#   "avg_stars": 4.466413668031315,
#   "total_reviews": 502,
#   "business_count": 10
# }
# {
#   "_id": "Massage Therapy",
#   "avg_stars": 4.464275248942612,
#   "total_reviews": 517,
#   "business_count": 20
# }
#
# ============================================================
#   Q1 - Bottom 5 categories by avg stars
# ============================================================
# {
#   "_id": "Appliances",
#   "avg_stars": 3.0808783017339167,
#   "total_reviews": 151,
#   "business_count": 11
# }
# {
#   "_id": "Oil Change Stations",
#   "avg_stars": 3.0458510357381794,
#   "total_reviews": 602,
#   "business_count": 33
# }
# {
#   "_id": "Drugstores",
#   "avg_stars": 2.8798887675185254,
#   "total_reviews": 315,
#   "business_count": 17
# }
# {
#   "_id": "Car Rental",
#   "avg_stars": 2.7859508676538116,
#   "total_reviews": 381,
#   "business_count": 13
# }
# {
#   "_id": "Mobile Phones",
#   "avg_stars": 2.7217010170357026,
#   "total_reviews": 168,
#   "business_count": 11
# }
#
# --- Q2 ---
#
# ============================================================
#   Q2 - Cities with strongest upward trend (slope)
# ============================================================
# [
#   "Lawnside",
#   1.1666666666666667
# ]
# [
#   "Lindenwold",
#   1.0714285714285714
# ]
# [
#   "Old Hickory",
#   0.7035714285714286
# ]
# [
#   "Swansea",
#   0.5779761904761905
# ]
# [
#   "Upper Southampton Township",
#   0.5714285714285714
# ]
#
# ============================================================
#   Q2 - Cities with strongest downward trend (slope)
# ============================================================
# [
#   "Fountainville",
#   -0.75
# ]
# [
#   "Boone",
#   -0.9523809523809522
# ]
# [
#   "Line Lexington",
#   -1.0
# ]
# [
#   "Florence Township",
#   -1.3
# ]
# [
#   "Evesham Township",
#   -1.3333333333333333
# ]
#
# --- Q3 ---
#
# ============================================================
#   Q3 - Avg stars by review count bucket
# ============================================================
# {
#   "_id": 1,
#   "avg_stars": 3.7268758216357325,
#   "business_count": 7643
# }
# {
#   "_id": 10,
#   "avg_stars": 3.7095100232262026,
#   "business_count": 2888
# }
# {
#   "_id": 50,
#   "avg_stars": 3.821546934080696,
#   "business_count": 572
# }
# {
#   "_id": 100,
#   "avg_stars": 3.9737533915392307,
#   "business_count": 331
# }
# {
#   "_id": 500,
#   "avg_stars": 3.998301394911575,
#   "business_count": 16
# }
# {
#   "_id": 1000,
#   "avg_stars": 4.111350188273265,
#   "business_count": 1
# }
#
# --- Q4 ---
#
# ============================================================
#   Q4 - Review behaviour by top categories
# ============================================================
# {
#   "_id": "Restaurants",
#   "avg_stars": 3.80948457320113,
#   "avg_text_length": 537.2412964604221,
#   "useful_per_review": 0.763058771395336,
#   "review_count": 144424,
#   "star_dist_1": 14408,
#   "star_dist_2": 12836,
#   "star_dist_3": 18187,
#   "star_dist_4": 39425,
#   "star_dist_5": 59568
# }
# {
#   "_id": "Food",
#   "avg_stars": 3.9409393029454436,
#   "avg_text_length": 516.9338034346638,
#   "useful_per_review": 0.8091872195418199,
#   "review_count": 59278,
#   "star_dist_1": 5058,
#   "star_dist_2": 4457,
#   "star_dist_3": 6716,
#   "star_dist_4": 15744,
#   "star_dist_5": 27303
# }
# {
#   "_id": "Nightlife",
#   "avg_stars": 3.8251447866133823,
#   "avg_text_length": 559.1181800696686,
#   "useful_per_review": 0.7500480841151455,
#   "review_count": 46793,
#   "star_dist_1": 4273,
#   "star_dist_2": 4083,
#   "star_dist_3": 6134,
#   "star_dist_4": 13366,
#   "star_dist_5": 18937
# }
# {
#   "_id": "Bars",
#   "avg_stars": 3.8197502165094126,
#   "avg_text_length": 557.7261497789325,
#   "useful_per_review": 0.735197593326952,
#   "review_count": 43878,
#   "star_dist_1": 3978,
#   "star_dist_2": 3870,
#   "star_dist_3": 5808,
#   "star_dist_4": 12649,
#   "star_dist_5": 17573
# }
# {
#   "_id": "American (New)",
#   "avg_stars": 3.838226879874725,
#   "avg_text_length": 586.2105580148764,
#   "useful_per_review": 0.7443009004125636,
#   "review_count": 33207,
#   "star_dist_1": 2825,
#   "star_dist_2": 3002,
#   "star_dist_3": 4507,
#   "star_dist_4": 9259,
#   "star_dist_5": 13614
# }
# {
#   "_id": "American (Traditional)",
#   "avg_stars": 3.7143358237749484,
#   "avg_text_length": 538.0209407555509,
#   "useful_per_review": 0.6936055280788523,
#   "review_count": 28509,
#   "star_dist_1": 3145,
#   "star_dist_2": 2767,
#   "star_dist_3": 4021,
#   "star_dist_4": 7730,
#   "star_dist_5": 10846
# }
# {
#   "_id": "Breakfast & Brunch",
#   "avg_stars": 3.9266673803661276,
#   "avg_text_length": 512.2034757163758,
#   "useful_per_review": 0.6238090140241944,
#   "review_count": 28023,
#   "star_dist_1": 2225,
#   "star_dist_2": 2208,
#   "star_dist_3": 3484,
#   "star_dist_4": 7586,
#   "star_dist_5": 12520
# }
# {
#   "_id": "Sandwiches",
#   "avg_stars": 3.9128120134598965,
#   "avg_text_length": 492.03917432574957,
#   "useful_per_review": 0.6896690271709105,
#   "review_count": 19911,
#   "star_dist_1": 1732,
#   "star_dist_2": 1561,
#   "star_dist_3": 2359,
#   "star_dist_4": 5318,
#   "star_dist_5": 8941
# }
# {
#   "_id": "Event Planning & Services",
#   "avg_stars": 3.7766609709518546,
#   "avg_text_length": 625.9303950145743,
#   "useful_per_review": 0.8949140617147452,
#   "review_count": 19898,
#   "star_dist_1": 2251,
#   "star_dist_2": 1799,
#   "star_dist_3": 2427,
#   "star_dist_4": 5087,
#   "star_dist_5": 8334
# }
# {
#   "_id": "Coffee & Tea",
#   "avg_stars": 3.9746338423184793,
#   "avg_text_length": 487.68569647865377,
#   "useful_per_review": 0.7843564973511997,
#   "review_count": 16045,
#   "star_dist_1": 1411,
#   "star_dist_2": 1162,
#   "star_dist_3": 1654,
#   "star_dist_4": 4014,
#   "star_dist_5": 7804
# }
# {
#   "_id": "Seafood",
#   "avg_stars": 3.7768014059753954,
#   "avg_text_length": 529.2039919658549,
#   "useful_per_review": 0.6449912126537786,
#   "review_count": 15932,
#   "star_dist_1": 1652,
#   "star_dist_2": 1490,
#   "star_dist_3": 2050,
#   "star_dist_4": 4310,
#   "star_dist_5": 6430
# }
# {
#   "_id": "Pizza",
#   "avg_stars": 3.684195939860043,
#   "avg_text_length": 514.4838217972701,
#   "useful_per_review": 0.7266680523799626,
#   "review_count": 14433,
#   "star_dist_1": 1829,
#   "star_dist_2": 1368,
#   "star_dist_3": 1780,
#   "star_dist_4": 4011,
#   "star_dist_5": 5445
# }
# {
#   "_id": "Burgers",
#   "avg_stars": 3.5854835326200964,
#   "avg_text_length": 539.4078036500944,
#   "useful_per_review": 0.7101601286623314,
#   "review_count": 14301,
#   "star_dist_1": 1974,
#   "star_dist_2": 1491,
#   "star_dist_3": 1995,
#   "star_dist_4": 3870,
#   "star_dist_5": 4971
# }
# {
#   "_id": "Mexican",
#   "avg_stars": 3.788607594936709,
#   "avg_text_length": 505.89553239017124,
#   "useful_per_review": 0.6967982129560685,
#   "review_count": 13430,
#   "star_dist_1": 1416,
#   "star_dist_2": 1325,
#   "star_dist_3": 1588,
#   "star_dist_4": 3454,
#   "star_dist_5": 5647
# }
# {
#   "_id": "Italian",
#   "avg_stars": 3.735062953071347,
#   "avg_text_length": 555.7856543304082,
#   "useful_per_review": 0.8798931705455932,
#   "review_count": 13105,
#   "star_dist_1": 1528,
#   "star_dist_2": 1295,
#   "star_dist_3": 1570,
#   "star_dist_4": 3440,
#   "star_dist_5": 5272
# }
#
# --- Q5 ---
#
# ============================================================
#   Q5 - Reviewing behaviour by tenure
# ============================================================
# {
#   "_id": 0,
#   "avg_stars": 3.866180713743356,
#   "avg_useful": 1.136188306757783,
#   "review_count": 32925
# }
# {
#   "_id": 1,
#   "avg_stars": 3.883915737298637,
#   "avg_useful": 1.1925154894671623,
#   "review_count": 20175
# }
# {
#   "_id": 2,
#   "avg_stars": 3.8869822148985738,
#   "avg_useful": 1.1568270924484345,
#   "review_count": 17599
# }
# {
#   "_id": 3,
#   "avg_stars": 3.934131736526946,
#   "avg_useful": 1.132499332545101,
#   "review_count": 26219
# }
# {
#   "_id": 5,
#   "avg_stars": 3.970960748516659,
#   "avg_useful": 1.0468393427658604,
#   "review_count": 17528
# }
# {
#   "_id": 8,
#   "avg_stars": 4.007326007326007,
#   "avg_useful": 1.0124542124542124,
#   "review_count": 2730
# }
# {
#   "_id": 12,
#   "avg_stars": 4.2727272727272725,
#   "avg_useful": 1.4090909090909092,
#   "review_count": 22
# }
# {
#   "_id": "20+",
#   "avg_stars": 4.5,
#   "avg_useful": 0.0,
#   "review_count": 2
# }
#
# --- Q6 ---
#
# ============================================================
#   Q6 - Elite vs non-elite metrics
# ============================================================
# {
#   "_id": true,
#   "mean_stars": 3.9108068097705404,
#   "mean_text_length": 764.9529484332593,
#   "mean_useful": 1.6374784110535405,
#   "review_count": 40530
# }
# {
#   "_id": false,
#   "mean_stars": 3.9043824181557323,
#   "mean_text_length": 514.8752836833181,
#   "mean_useful": 0.8647058823529412,
#   "review_count": 76670
# }
#
# --- Q7 ---
#
# ============================================================
#   Q7 - Checkin activity vs stars by category
# ============================================================
# {
#   "_id": "French",
#   "avg_checkins": 1230.8,
#   "avg_stars": 4.0235197068290045,
#   "business_count": 10
# }
# {
#   "_id": "Cajun/Creole",
#   "avg_checkins": 830.8695652173913,
#   "avg_stars": 3.672003409575907,
#   "business_count": 23
# }
# {
#   "_id": "Beer Bar",
#   "avg_checkins": 822.1333333333333,
#   "avg_stars": 3.8681171677979944,
#   "business_count": 15
# }
# {
#   "_id": "Public Services & Government",
#   "avg_checkins": 792.0,
#   "avg_stars": 3.769682655203017,
#   "business_count": 13
# }
# {
#   "_id": "Breweries",
#   "avg_checkins": 595.9545454545455,
#   "avg_stars": 3.935398056165034,
#   "business_count": 22
# }
# {
#   "_id": "Vietnamese",
#   "avg_checkins": 587.5,
#   "avg_stars": 3.967912323134633,
#   "business_count": 18
# }
# {
#   "_id": "Health Markets",
#   "avg_checkins": 583.4666666666667,
#   "avg_stars": 3.95684220259374,
#   "business_count": 15
# }
# {
#   "_id": "Organic Stores",
#   "avg_checkins": 555.9090909090909,
#   "avg_stars": 3.939801522241714,
#   "business_count": 11
# }
# {
#   "_id": "Tapas/Small Plates",
#   "avg_checkins": 544.2727272727273,
#   "avg_stars": 3.923830073638429,
#   "business_count": 11
# }
# {
#   "_id": "Cocktail Bars",
#   "avg_checkins": 511.6279069767442,
#   "avg_stars": 3.915968226767645,
#   "business_count": 43
# }
# {
#   "_id": "Bubble Tea",
#   "avg_checkins": 509.9,
#   "avg_stars": 4.150940274032168,
#   "business_count": 10
# }
# {
#   "_id": "Grocery",
#   "avg_checkins": 501.3731343283582,
#   "avg_stars": 3.692102573847754,
#   "business_count": 67
# }
# {
#   "_id": "Beer",
#   "avg_checkins": 482.2244897959184,
#   "avg_stars": 4.077944513536252,
#   "business_count": 49
# }
# {
#   "_id": "Wine & Spirits",
#   "avg_checkins": 482.2244897959184,
#   "avg_stars": 4.077944513536252,
#   "business_count": 49
# }
# {
#   "_id": "Music Venues",
#   "avg_checkins": 465.77272727272725,
#   "avg_stars": 3.8855522471204154,
#   "business_count": 22
# }
# {
#   "_id": "Pubs",
#   "avg_checkins": 459.5660377358491,
#   "avg_stars": 3.6220099847086966,
#   "business_count": 53
# }
# {
#   "_id": "Seafood",
#   "avg_checkins": 449.7083333333333,
#   "avg_stars": 3.6465751122956727,
#   "business_count": 72
# }
# {
#   "_id": "Donuts",
#   "avg_checkins": 445.85714285714283,
#   "avg_stars": 3.660754632542049,
#   "business_count": 28
# }
# {
#   "_id": "Bars",
#   "avg_checkins": 441.024,
#   "avg_stars": 3.6017321364320343,
#   "business_count": 250
# }
# {
#   "_id": "Wine Bars",
#   "avg_checkins": 438.76666666666665,
#   "avg_stars": 3.774402049764451,
#   "business_count": 30
# }
#
# All queries done.

# %%
import json
from neo4j import GraphDatabase

URI = "neo4j://localhost:7687"
AUTH = ("neo4j", "Password@123")

DATA_DIR = r"/home/pranavanand/Projects/DSM/Yelp-Dataset-Assignment/Yelp-JSON"

# Limits — keep small for Neo4j
BIZ_LIMIT    = None          # load all businesses (only ~150k, manageable)
USER_LIMIT   = 20_000
REVIEW_LIMIT = 80_000

driver = GraphDatabase.driver(URI, auth=AUTH)

def run(session, query, **kwargs):
    session.run(query, **kwargs)

# ── Helper to load jsonl ─────────────────────────────────────────────────────
def load_jsonl(path, limit=None):
    with open(path, "r", encoding="utf-8") as f:
        for i, line in enumerate(f):
            if limit and i >= limit:
                break
            yield json.loads(line)

with driver.session() as session:

    # ── Constraints ─────────────────────────────────────────────────────────
    print("Creating constraints...")
    session.run("CREATE CONSTRAINT IF NOT EXISTS FOR (b:Business) REQUIRE b.business_id IS UNIQUE")
    session.run("CREATE CONSTRAINT IF NOT EXISTS FOR (u:User) REQUIRE u.user_id IS UNIQUE")
    session.run("CREATE CONSTRAINT IF NOT EXISTS FOR (c:Category) REQUIRE c.name IS UNIQUE")
    session.run("CREATE CONSTRAINT IF NOT EXISTS FOR (s:State) REQUIRE s.name IS UNIQUE")
    session.run("CREATE CONSTRAINT IF NOT EXISTS FOR (r:Review) REQUIRE r.review_id IS UNIQUE")

    # ── Load Businesses + Categories ─────────────────────────────────────────
    print("Loading businesses...")
    batch = []
    for b in load_jsonl(f"{DATA_DIR}/yelp_academic_dataset_business.json", BIZ_LIMIT):
        cats = [c.strip() for c in b.get("categories", "") .split(",")] if b.get("categories") else []
        batch.append({
            "business_id": b["business_id"],
            "name": b["name"],
            "city": b.get("city", ""),
            "state": b.get("state", ""),
            "stars": b.get("stars", 0),
            "review_count": b.get("review_count", 0),
            "is_open": b.get("is_open", 0),
            "categories": cats
        })
        if len(batch) == 2000:
            session.run("""
                UNWIND $batch AS b
                MERGE (biz:Business {business_id: b.business_id})
                SET biz.name = b.name,
                    biz.city = b.city,
                    biz.state = b.state,
                    biz.stars = b.stars,
                    biz.review_count = b.review_count,
                    biz.is_open = b.is_open
                WITH biz, b
                UNWIND b.categories AS catName
                MERGE (c:Category {name: catName})
                MERGE (biz)-[:IN_CATEGORY]->(c)
            """, batch=batch)
            batch = []
    if batch:
        session.run("""
            UNWIND $batch AS b
            MERGE (biz:Business {business_id: b.business_id})
            SET biz.name = b.name,
                biz.city = b.city,
                biz.state = b.state,
                biz.stars = b.stars,
                biz.review_count = b.review_count,
                biz.is_open = b.is_open
            WITH biz, b
            UNWIND b.categories AS catName
            MERGE (c:Category {name: catName})
            MERGE (biz)-[:IN_CATEGORY]->(c)
        """, batch=batch)
    print("  Businesses done.")

    # ── Load Users (subset) ─────────────────────────────────────────────────
    print("Loading users...")
    batch = []
    user_ids_loaded = set()
    for u in load_jsonl(f"{DATA_DIR}/yelp_academic_dataset_user.json", USER_LIMIT):
        user_ids_loaded.add(u["user_id"])
        batch.append({
            "user_id": u["user_id"],
            "name": u.get("name", ""),
            "review_count": u.get("review_count", 0),
            "average_stars": u.get("average_stars", 0),
            "fans": u.get("fans", 0),
            "yelping_since": u.get("yelping_since", ""),
            "elite": u.get("elite", ""),
            "friends": [f.strip() for f in u.get("friends", "").split(",") if f.strip()][:50]  # cap friends
        })
        if len(batch) == 1000:
            session.run("""
                UNWIND $batch AS u
                MERGE (usr:User {user_id: u.user_id})
                SET usr.name = u.name,
                    usr.review_count = u.review_count,
                    usr.average_stars = u.average_stars,
                    usr.fans = u.fans,
                    usr.yelping_since = u.yelping_since,
                    usr.elite = u.elite
            """, batch=batch)
            batch = []
    if batch:
        session.run("""
            UNWIND $batch AS u
            MERGE (usr:User {user_id: u.user_id})
            SET usr.name = u.name,
                usr.review_count = u.review_count,
                usr.average_stars = u.average_stars,
                usr.fans = u.fans,
                usr.yelping_since = u.yelping_since,
                usr.elite = u.elite
        """, batch=batch)
    print("  Users done.")

    # ── Friend relationships (only within loaded users) ──────────────────────
    print("Creating FRIENDS relationships...")
    batch = []
    for u in load_jsonl(f"{DATA_DIR}/yelp_academic_dataset_user.json", USER_LIMIT):
        friends = [f.strip() for f in u.get("friends", "").split(",") if f.strip()]
        for fid in friends[:20]:   # cap at 20 friends per user
            if fid in user_ids_loaded:
                batch.append({"uid": u["user_id"], "fid": fid})
        if len(batch) >= 5000:
            session.run("""
                UNWIND $batch AS rel
                MATCH (a:User {user_id: rel.uid})
                MATCH (b:User {user_id: rel.fid})
                MERGE (a)-[:FRIENDS_WITH]->(b)
            """, batch=batch)
            batch = []
    if batch:
        session.run("""
            UNWIND $batch AS rel
            MATCH (a:User {user_id: rel.uid})
            MATCH (b:User {user_id: rel.fid})
            MERGE (a)-[:FRIENDS_WITH]->(b)
        """, batch=batch)
    print("  Friend relationships done.")

    # ── Load Reviews ─────────────────────────────────────────────────────────
    print("Loading reviews...")
    batch = []
    for r in load_jsonl(f"{DATA_DIR}/yelp_academic_dataset_review.json", REVIEW_LIMIT):
        batch.append({
            "review_id": r["review_id"],
            "user_id": r["user_id"],
            "business_id": r["business_id"],
            "stars": r.get("stars", 0),
            "date": r.get("date", ""),
            "useful": r.get("useful", 0)
        })
        if len(batch) == 2000:
            session.run("""
                UNWIND $batch AS r
                MATCH (u:User {user_id: r.user_id})
                MATCH (b:Business {business_id: r.business_id})
                MERGE (rev:Review {review_id: r.review_id})
                SET rev.stars = r.stars,
                    rev.date = r.date,
                    rev.useful = r.useful
                MERGE (u)-[:WROTE]->(rev)
                MERGE (rev)-[:REVIEWS]->(b)
            """, batch=batch)
            batch = []
    if batch:
        session.run("""
            UNWIND $batch AS r
            MATCH (u:User {user_id: r.user_id})
            MATCH (b:Business {business_id: r.business_id})
            MERGE (rev:Review {review_id: r.review_id})
            SET rev.stars = r.stars,
                rev.date = r.date,
                rev.useful = r.useful
            MERGE (u)-[:WROTE]->(rev)
            MERGE (rev)-[:REVIEWS]->(b)
        """, batch=batch)
    print("  Reviews done.")

driver.close()
print("\nNeo4j load complete.")
# Out:
# Creating constraints...
# Loading businesses...
#   Businesses done.
# Loading users...
#   Users done.
# Creating FRIENDS relationships...
#   Friend relationships done.
# Loading reviews...
#   Reviews done.
#
# Neo4j load complete.

# %%
import json
from neo4j import GraphDatabase

URI = "neo4j://localhost:7687"
AUTH = ("neo4j", "Password@123")

driver = GraphDatabase.driver(URI, auth=AUTH)

def run_query(label, cypher, **params):
    with driver.session() as session:
        result = session.run(cypher, **params)
        records = [dict(r) for r in result]
        print(f"\n{'='*60}\n  {label}\n{'='*60}")
        for r in records[:20]:
            print(json.dumps(r, default=str, indent=2))
        return records

# ── N1: Top 10 users by friend count ─────────────────────────────────────────
run_query("N1 - Top 10 users by friend count",
"""
MATCH (u:User)-[:FRIENDS_WITH]->(f:User)
WITH u, COUNT(f) AS friend_count
ORDER BY friend_count DESC
LIMIT 10
MATCH (u)-[:WROTE]->(r:Review)
WITH u, friend_count, COUNT(r) AS total_reviews, AVG(r.stars) AS mean_stars
RETURN u.user_id AS user_id,
       u.name AS name,
       friend_count,
       total_reviews,
       round(mean_stars * 100) / 100.0 AS mean_stars
ORDER BY friend_count DESC
""")

# ── N2: Top 3 businesses per state by avg stars (min 50 reviews) ──────────────
run_query("N2 - Top 3 businesses per state by avg stars",
"""
MATCH (rev:Review)-[:REVIEWS]->(b:Business)
WITH b, AVG(rev.stars) AS avg_stars, COUNT(rev) AS review_count
WHERE review_count >= 50
WITH b.state AS state,
     b.name AS name,
     b.city AS city,
     avg_stars,
     review_count,
     [(b)-[:IN_CATEGORY]->(c) | c.name][0] AS category
ORDER BY state, avg_stars DESC
WITH state,
     COLLECT({name: name, city: city, avg_stars: avg_stars,
              review_count: review_count, category: category})[..3] AS top3
RETURN state, top3
ORDER BY state
""")

# ── N3: Top 10 users by distinct cities reviewed ──────────────────────────────
run_query("N3 - Top 10 users reviewed across most cities",
"""
MATCH (u:User)-[:WROTE]->(r:Review)-[:REVIEWS]->(b:Business)
WITH u, b.city AS city, AVG(r.stars) AS city_stars
WITH u, COUNT(DISTINCT city) AS cities_covered,
     COLLECT({city: city, avg_stars: city_stars}) AS city_stats
ORDER BY cities_covered DESC
LIMIT 10
RETURN u.user_id AS user_id,
       u.name AS name,
       cities_covered,
       city_stats
""")

# ── N4: Category-specific vs overall mean stars ───────────────────────────────
CATEGORY = "Restaurants"   # change if you want a different one
run_query(f"N4 - Users who reviewed 5+ {CATEGORY} businesses: category vs overall avg",
f"""
MATCH (u:User)-[:WROTE]->(r:Review)-[:REVIEWS]->(b:Business)-[:IN_CATEGORY]->(c:Category)
WHERE c.name = $cat
WITH u, COUNT(DISTINCT b) AS biz_count, AVG(r.stars) AS cat_avg
WHERE biz_count >= 5
MATCH (u)-[:WROTE]->(allR:Review)
WITH u, biz_count, cat_avg, AVG(allR.stars) AS overall_avg
RETURN u.user_id AS user_id,
       u.name AS name,
       biz_count,
       round(cat_avg * 100) / 100.0 AS category_avg_stars,
       round(overall_avg * 100) / 100.0 AS overall_avg_stars,
       round((cat_avg - overall_avg) * 100) / 100.0 AS difference
ORDER BY biz_count DESC
LIMIT 20
""", cat=CATEGORY)

# ── N5: Reproduce MongoDB Q6 (elite vs non-elite) in Cypher ──────────────────
run_query("N5 - Elite vs non-elite (reproducing Q6 in Cypher)",
"""
MATCH (u:User)-[:WROTE]->(r:Review)
WITH u,
     CASE WHEN u.elite IS NOT NULL AND u.elite <> '' AND u.elite <> 'None'
          THEN true ELSE false END AS is_elite,
     r.stars AS stars
WITH is_elite,
     COUNT(*) AS review_count,
     AVG(stars) AS mean_stars
RETURN is_elite, review_count, round(mean_stars * 100) / 100.0 AS mean_stars
ORDER BY is_elite DESC
""")

driver.close()
print("\nNeo4j queries done.")
# Out:
# ============================================================
#   N1 - Top 10 users by friend count
# ============================================================
# {
#   "user_id": "sO5b8D6Mj5rQj7EFSz557g",
#   "name": "George",
#   "friend_count": 17,
#   "total_reviews": 4,
#   "mean_stars": 4.0
# }
# {
#   "user_id": "eQ3KXZKdD4hP-US4WI4lbg",
#   "name": "Merritt",
#   "friend_count": 16,
#   "total_reviews": 3,
#   "mean_stars": 3.67
# }
# {
#   "user_id": "Wshkpj8aHWuzIeca1QxWTA",
#   "name": "Alexandra",
#   "friend_count": 16,
#   "total_reviews": 3,
#   "mean_stars": 3.0
# }
# {
#   "user_id": "VAJBPYAhdUCB38Xm1Sh_UA",
#   "name": "Patti",
#   "friend_count": 16,
#   "total_reviews": 1,
#   "mean_stars": 4.0
# }
# {
#   "user_id": "Bnf-KvDhT8WXrpv2WJEOQQ",
#   "name": "Leah",
#   "friend_count": 16,
#   "total_reviews": 1,
#   "mean_stars": 4.0
# }
# {
#   "user_id": "WZ4vEAuJdBgHrnIZlBQLig",
#   "name": "Erika",
#   "friend_count": 15,
#   "total_reviews": 4,
#   "mean_stars": 5.0
# }
# {
#   "user_id": "ytIvCKe0uuqv2ofTqAdxOg",
#   "name": "Daria",
#   "friend_count": 15,
#   "total_reviews": 3,
#   "mean_stars": 4.0
# }
#
# ============================================================
#   N2 - Top 3 businesses per state by avg stars
# ============================================================
# {
#   "state": "CA",
#   "top3": [
#     {
#       "avg_stars": 3.961538461538462,
#       "city": "Santa Barbara",
#       "name": "Santa Barbara Shellfish Company",
#       "review_count": 52,
#       "category": "Bars"
#     }
#   ]
# }
# {
#   "state": "LA",
#   "top3": [
#     {
#       "avg_stars": 4.387096774193548,
#       "city": "New Orleans",
#       "name": "Surrey's Caf\u00e9 & Juice Bar",
#       "review_count": 62,
#       "category": "Vegetarian"
#     },
#     {
#       "avg_stars": 4.044871794871792,
#       "city": "New Orleans",
#       "name": "Luke",
#       "review_count": 156,
#       "category": "Cajun/Creole"
#     }
#   ]
# }
# {
#   "state": "NV",
#   "top3": [
#     {
#       "avg_stars": 3.658536585365854,
#       "city": "Reno",
#       "name": "Peppermill Reno",
#       "review_count": 82,
#       "category": "Event Planning & Services"
#     }
#   ]
# }
# {
#   "state": "PA",
#   "top3": [
#     {
#       "avg_stars": 4.062500000000002,
#       "city": "Philadelphia",
#       "name": "Honey's Sit-N-Eat",
#       "review_count": 64,
#       "category": "Southern"
#     },
#     {
#       "avg_stars": 3.9838709677419364,
#       "city": "Philadelphia",
#       "name": "Village Whiskey",
#       "review_count": 62,
#       "category": "American (New)"
#     },
#     {
#       "avg_stars": 3.6346153846153846,
#       "city": "Philadelphia",
#       "name": "Jones",
#       "review_count": 52,
#       "category": "American (New)"
#     }
#   ]
# }
# {
#   "state": "TN",
#   "top3": [
#     {
#       "avg_stars": 3.788461538461538,
#       "city": "Nashville",
#       "name": "The Pancake Pantry",
#       "review_count": 52,
#       "category": "Breakfast & Brunch"
#     }
#   ]
# }
#
# ============================================================
#   N3 - Top 10 users reviewed across most cities
# ============================================================
# {
#   "user_id": "_BcWyKQL16ndpBdggh2kNA",
#   "name": "Karen",
#   "cities_covered": 13,
#   "city_stats": [
#     {
#       "city": "Media",
#       "avg_stars": 3.75
#     },
#     {
#       "city": "Doylestown",
#       "avg_stars": 3.3333333333333335
#     },
#     {
#       "city": "Philadelphia",
#       "avg_stars": 3.678571428571429
#     },
#     {
#       "city": "Wilmington",
#       "avg_stars": 4.0
#     },
#     {
#       "city": "Springfield",
#       "avg_stars": 4.0
#     },
#     {
#       "city": "Wayne",
#       "avg_stars": 4.0
#     },
#     {
#       "city": "Drexel Hill",
#       "avg_stars": 5.0
#     },
#     {
#       "city": "Broomall",
#       "avg_stars": 1.0
#     },
#     {
#       "city": "Warrington",
#       "avg_stars": 4.0
#     },
#     {
#       "city": "Newtown Square",
#       "avg_stars": 3.0
#     },
#     {
#       "city": "Plymouth Meeting",
#       "avg_stars": 3.0
#     },
#     {
#       "city": "Paoli",
#       "avg_stars": 4.0
#     },
#     {
#       "city": "Glen Mills",
#       "avg_stars": 4.0
#     }
#   ]
# }
# {
#   "user_id": "ouODopBKF3AqfCkuQEnrDg",
#   "name": "Danan",
#   "cities_covered": 11,
#   "city_stats": [
#     {
#       "city": "North Wales",
#       "avg_stars": 2.0
#     },
#     {
#       "city": "King of Prussia",
#       "avg_stars": 4.0
#     },
#     {
#       "city": "Blue Bell",
#       "avg_stars": 4.5
#     },
#     {
#       "city": "Wayne",
#       "avg_stars": 4.0
#     },
#     {
#       "city": "East Norriton",
#       "avg_stars": 3.0
#     },
#     {
#       "city": "Bryn Mawr",
#       "avg_stars": 4.5
#     },
#     {
#       "city": "Upper Darby",
#       "avg_stars": 4.0
#     },
#     {
#       "city": "Radnor",
#       "avg_stars": 2.0
#     },
#     {
#       "city": "Philadelphia",
#       "avg_stars": 4.0
#     },
#     {
#       "city": "Bensalem",
#       "avg_stars": 2.0
#     },
#     {
#       "city": "Jenkintown",
#       "avg_stars": 3.0
#     }
#   ]
# }
# {
#   "user_id": "qjfMBIZpQT9DDtw_BWCopQ",
#   "name": "Rachel",
#   "cities_covered": 9,
#   "city_stats": [
#     {
#       "city": "Tampa",
#       "avg_stars": 3.2857142857142856
#     },
#     {
#       "city": "Zephyrhills",
#       "avg_stars": 3.0
#     },
#     {
#       "city": "Dunedin",
#       "avg_stars": 3.0
#     },
#     {
#       "city": "Wesley Chapel",
#       "avg_stars": 4.0
#     },
#     {
#       "city": "Saint Pete Beach",
#       "avg_stars": 5.0
#     },
#     {
#       "city": "Lutz",
#       "avg_stars": 5.0
#     },
#     {
#       "city": "Land o lakes",
#       "avg_stars": 3.0
#     },
#     {
#       "city": "St. Petersburg",
#       "avg_stars": 5.0
#     },
#     {
#       "city": "St Pete Beach",
#       "avg_stars": 2.0
#     }
#   ]
# }
# {
#   "user_id": "GG0mFsEXb-02_dzFPqRV1Q",
#   "name": "Mandy",
#   "cities_covered": 8,
#   "city_stats": [
#     {
#       "city": "Philadelphia",
#       "avg_stars": 2.857142857142857
#     },
#     {
#       "city": "Eddystone",
#       "avg_stars": 4.0
#     },
#     {
#       "city": "Media",
#       "avg_stars": 3.0
#     },
#     {
#       "city": "Woodlyn",
#       "avg_stars": 2.0
#     },
#     {
#       "city": "Aston",
#       "avg_stars": 3.0
#     },
#     {
#       "city": "Wilmington",
#       "avg_stars": 3.0
#     },
#     {
#       "city": "Ridley Park",
#       "avg_stars": 1.0
#     },
#     {
#       "city": "Crum Lynne",
#       "avg_stars": 1.0
#     }
#   ]
# }
# {
#   "user_id": "Um5bfs5DH6eizgjH3xZsvg",
#   "name": "Dianna",
#   "cities_covered": 7,
#   "city_stats": [
#     {
#       "city": "Palm Harbor",
#       "avg_stars": 3.5
#     },
#     {
#       "city": "Tampa",
#       "avg_stars": 4.125
#     },
#     {
#       "city": "St. Petersburg",
#       "avg_stars": 3.0
#     },
#     {
#       "city": "Clearwater",
#       "avg_stars": 3.5
#     },
#     {
#       "city": "Temple Terrace",
#       "avg_stars": 2.0
#     },
#     {
#       "city": "Oldsmar",
#       "avg_stars": 4.0
#     },
#     {
#       "city": "Tarpon Springs",
#       "avg_stars": 3.0
#     }
#   ]
# }
# {
#   "user_id": "eTvp_hYnsrI5-ow_sQ31_g",
#   "name": "Patt",
#   "cities_covered": 7,
#   "city_stats": [
#     {
#       "city": "Chesterfield",
#       "avg_stars": 3.5
#     },
#     {
#       "city": "Fairview Heights",
#       "avg_stars": 5.0
#     },
#     {
#       "city": "Saint Louis",
#       "avg_stars": 3.888888888888889
#     },
#     {
#       "city": "Ballwin",
#       "avg_stars": 3.0
#     },
#     {
#       "city": "Frontenac",
#       "avg_stars": 5.0
#     },
#     {
#       "city": "Fenton",
#       "avg_stars": 5.0
#     },
#     {
#       "city": "University City",
#       "avg_stars": 5.0
#     }
#   ]
# }
# {
#   "user_id": "Xw7ZjaGfr0WNVt6s_5KZfA",
#   "name": "Marielle",
#   "cities_covered": 7,
#   "city_stats": [
#     {
#       "city": "New Orleans",
#       "avg_stars": 4.3125
#     },
#     {
#       "city": "Harvey",
#       "avg_stars": 4.0
#     },
#     {
#       "city": "Bridge City",
#       "avg_stars": 5.0
#     },
#     {
#       "city": "Metairie",
#       "avg_stars": 4.0
#     },
#     {
#       "city": "Gretna",
#       "avg_stars": 3.0
#     },
#     {
#       "city": "Kenner",
#       "avg_stars": 3.0
#     },
#     {
#       "city": "Belle Chasse",
#       "avg_stars": 4.0
#     }
#   ]
# }
# {
#   "user_id": "Oi1qbcz2m2SnwUeztGYcnQ",
#   "name": "Steven",
#   "cities_covered": 7,
#   "city_stats": [
#     {
#       "city": "Springfield",
#       "avg_stars": 4.0
#     },
#     {
#       "city": "Philadelphia",
#       "avg_stars": 4.0
#     },
#     {
#       "city": "West Chester",
#       "avg_stars": 4.0
#     },
#     {
#       "city": "Media",
#       "avg_stars": 4.0
#     },
#     {
#       "city": "Bryn Mawr",
#       "avg_stars": 4.0
#     },
#     {
#       "city": "Primos-Secane",
#       "avg_stars": 4.0
#     },
#     {
#       "city": "Wilmington",
#       "avg_stars": 4.0
#     }
#   ]
# }
# {
#   "user_id": "zQTEbn5nWGPypxOf2uRPmg",
#   "name": "Katie",
#   "cities_covered": 7,
#   "city_stats": [
#     {
#       "city": "Des Peres",
#       "avg_stars": 5.0
#     },
#     {
#       "city": "Ballwin",
#       "avg_stars": 4.0
#     },
#     {
#       "city": "Saint Louis",
#       "avg_stars": 3.5
#     },
#     {
#       "city": "Clayton",
#       "avg_stars": 5.0
#     },
#     {
#       "city": "Indianapolis",
#       "avg_stars": 3.0
#     },
#     {
#       "city": "Maplewood",
#       "avg_stars": 3.0
#     },
#     {
#       "city": "Kirkwood",
#       "avg_stars": 5.0
#     }
#   ]
# }
# {
#   "user_id": "Nxr5C4m0edwetAeRUacP6A",
#   "name": "Christopher",
#   "cities_covered": 7,
#   "city_stats": [
#     {
#       "city": "Safety Harbor",
#       "avg_stars": 4.0
#     },
#     {
#       "city": "Palm Harbor",
#       "avg_stars": 5.0
#     },
#     {
#       "city": "Clearwater",
#       "avg_stars": 3.0
#     },
#     {
#       "city": "Tarpon Springs",
#       "avg_stars": 4.0
#     },
#     {
#       "city": "Dunedin",
#       "avg_stars": 4.0
#     },
#     {
#       "city": "Tampa",
#       "avg_stars": 3.5
#     },
#     {
#       "city": "Largo",
#       "avg_stars": 4.0
#     }
#   ]
# }
#
# ============================================================
#   N4 - Users who reviewed 5+ Restaurants businesses: category vs overall avg
# ============================================================
# {
#   "user_id": "_BcWyKQL16ndpBdggh2kNA",
#   "name": "Karen",
#   "biz_count": 24,
#   "category_avg_stars": 3.54,
#   "overall_avg_stars": 3.67,
#   "difference": -0.13
# }
# {
#   "user_id": "nnImk681KaRqUVHlSfZjGQ",
#   "name": "Carlos",
#   "biz_count": 14,
#   "category_avg_stars": 4.14,
#   "overall_avg_stars": 4.2,
#   "difference": -0.06
# }
# {
#   "user_id": "2iS1vg5TYpV_iEiNC8osTg",
#   "name": "Peter",
#   "biz_count": 13,
#   "category_avg_stars": 3.23,
#   "overall_avg_stars": 3.29,
#   "difference": -0.05
# }
# {
#   "user_id": "0Igx-a1wAstiBDerGxXk2A",
#   "name": "Jen",
#   "biz_count": 13,
#   "category_avg_stars": 3.85,
#   "overall_avg_stars": 4.08,
#   "difference": -0.23
# }
# {
#   "user_id": "ouODopBKF3AqfCkuQEnrDg",
#   "name": "Danan",
#   "biz_count": 13,
#   "category_avg_stars": 3.53,
#   "overall_avg_stars": 3.56,
#   "difference": -0.02
# }
# {
#   "user_id": "Xw7ZjaGfr0WNVt6s_5KZfA",
#   "name": "Marielle",
#   "biz_count": 13,
#   "category_avg_stars": 3.85,
#   "overall_avg_stars": 4.07,
#   "difference": -0.23
# }
# {
#   "user_id": "84HvpQDxcHWmbMDfs8IEYw",
#   "name": "Chrissy",
#   "biz_count": 12,
#   "category_avg_stars": 3.42,
#   "overall_avg_stars": 3.56,
#   "difference": -0.15
# }
# {
#   "user_id": "CfX4sTIFFNaRchNswqhVfg",
#   "name": "Christopher",
#   "biz_count": 12,
#   "category_avg_stars": 4.23,
#   "overall_avg_stars": 4.12,
#   "difference": 0.11
# }
# {
#   "user_id": "qjfMBIZpQT9DDtw_BWCopQ",
#   "name": "Rachel",
#   "biz_count": 12,
#   "category_avg_stars": 3.67,
#   "overall_avg_stars": 3.59,
#   "difference": 0.08
# }
# {
#   "user_id": "2XKlUjHGk9z-2ckFMcBEHw",
#   "name": "Sheena",
#   "biz_count": 11,
#   "category_avg_stars": 3.91,
#   "overall_avg_stars": 4.0,
#   "difference": -0.09
# }
# {
#   "user_id": "Jt3GylPuH64uA3zTdbMdCg",
#   "name": "Dana",
#   "biz_count": 11,
#   "category_avg_stars": 4.5,
#   "overall_avg_stars": 4.5,
#   "difference": 0.0
# }
# {
#   "user_id": "sLqm9fRo_u81kJCIRdzrMg",
#   "name": "Jennifer",
#   "biz_count": 11,
#   "category_avg_stars": 3.5,
#   "overall_avg_stars": 3.5,
#   "difference": 0.0
# }
# {
#   "user_id": "lYQk0R6sPfo3WeX-l_5BuA",
#   "name": "Christopher",
#   "biz_count": 11,
#   "category_avg_stars": 3.55,
#   "overall_avg_stars": 3.47,
#   "difference": 0.08
# }
# {
#   "user_id": "GG0mFsEXb-02_dzFPqRV1Q",
#   "name": "Mandy",
#   "biz_count": 10,
#   "category_avg_stars": 2.82,
#   "overall_avg_stars": 2.64,
#   "difference": 0.18
# }
# {
#   "user_id": "IpLRJY4CP3fXtlEd8Y4GFQ",
#   "name": "Robyn",
#   "biz_count": 10,
#   "category_avg_stars": 2.83,
#   "overall_avg_stars": 2.77,
#   "difference": 0.06
# }
# {
#   "user_id": "mWamaq-Awy6tf7U4bCtT1A",
#   "name": "Kelly",
#   "biz_count": 10,
#   "category_avg_stars": 4.1,
#   "overall_avg_stars": 3.92,
#   "difference": 0.18
# }
# {
#   "user_id": "mzL0zHFGyd9866OUljq49g",
#   "name": "Vinny",
#   "biz_count": 10,
#   "category_avg_stars": 4.1,
#   "overall_avg_stars": 4.21,
#   "difference": -0.11
# }
# {
#   "user_id": "Hxx8FmhpxiugIrGRh8RDOg",
#   "name": "Tom",
#   "biz_count": 10,
#   "category_avg_stars": 4.0,
#   "overall_avg_stars": 4.0,
#   "difference": 0.0
# }
# {
#   "user_id": "eTvp_hYnsrI5-ow_sQ31_g",
#   "name": "Patt",
#   "biz_count": 10,
#   "category_avg_stars": 4.1,
#   "overall_avg_stars": 4.06,
#   "difference": 0.04
# }
# {
#   "user_id": "Um5bfs5DH6eizgjH3xZsvg",
#   "name": "Dianna",
#   "biz_count": 10,
#   "category_avg_stars": 3.6,
#   "overall_avg_stars": 3.68,
#   "difference": -0.08
# }
#
# ============================================================
#   N5 - Elite vs non-elite (reproducing Q6 in Cypher)
# ============================================================
# {
#   "is_elite": true,
#   "review_count": 7239,
#   "mean_stars": 3.84
# }
# {
#   "is_elite": false,
#   "review_count": 5200,
#   "mean_stars": 3.88
# }
#
# Neo4j queries done.
